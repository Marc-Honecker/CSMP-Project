# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os
os.chdir("/content/drive/My Drive/CSMP-Project")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
file_path = "data/RoughContact/pulloff4AIlabelled"

df = pd.read_csv(file_path+'.csv',  sep=";", header=0, names=['#Hurst', '#L', '#lambdaR', '#lambdaS', '#surfaceEnergy', '#rho', '#pulloff'])

# %%
df
# Out:
#     #Hurst    #L  #lambdaR  #lambdaS  #surfaceEnergy      #rho      #pulloff
# 0      0.8   512       256         4        0.008652  0.037603  4.020000e-07
# 1      0.8   512       256         4        0.017304  0.059691  1.000000e-06
# 2      0.8   512       256         4        0.034609  0.094753  2.800000e-06
# 3      0.8   512       256         4        0.060566  0.137601  6.760000e-06
# 4      0.8   512       256         4        0.112480  0.207899  2.940000e-05
# ..     ...   ...       ...       ...             ...       ...           ...
# 91     0.8  1024       128         2        0.951758  0.863281  2.372370e-02
# 92     0.8  1024       128         2        1.384375  1.108248  4.828920e-02
# 93     0.8  1024       128         2        1.990039  1.411591  8.272820e-02
# 94     0.8  1024       128         2        2.768750  1.759234  1.192725e-01
# 95     0.8  1024       128         2        3.893555  2.208168  2.017273e-01
#
# [96 rows x 7 columns]

# %%
df.to_csv(file_path+'.csv', sep=",", index=False)
