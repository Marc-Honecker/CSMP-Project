# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os
os.chdir("/content/drive/My Drive/CSMP-Project")
# Out:
# Mounted at /content/drive

# %%
# !pip3 install -q torch torchvision torchaudio

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
labeled_data_file = 'data/HertzianContact/dataWithLabelled.csv'
unlabeled_data_file = 'data/HertzianContact/dataWithunLabelled.csv'

column_names = ['radius Curvature', 'surface Energy', 'pulloff Force']

labeled_data = pd.read_csv(labeled_data_file)
unlabeled_data = pd.read_csv(unlabeled_data_file)

# for simulating the real data, we only use 100 labeled samples
train_dataset = labeled_data.sample(frac=0.10, random_state=0)
test_dataset = labeled_data.drop(train_dataset.index)

train_dataset = pd.concat([train_dataset, unlabeled_data], ignore_index=True).copy()

train_dataset.tail()
# Out:
#        radius Curvature  surface Energy  pulloff Force
# 10095          0.095201        0.047696            NaN
# 10096          0.040935        0.002560            NaN
# 10097          0.055987        0.078978            NaN
# 10098          0.052197        0.069240            NaN
# 10099          0.072977        0.031353            NaN

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('pulloff Force')
test_labels = test_features.pop('pulloff Force')

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(np.array(train_features))
print(normalizer.mean.numpy())
# Out:
# [[0.04999825 0.05000268]]

# %%
# model definition
