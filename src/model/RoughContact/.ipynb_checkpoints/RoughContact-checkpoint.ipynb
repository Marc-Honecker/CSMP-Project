# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data_file = '../../../data/RoughContact/pulloff4AIlabelled.csv'

column_names = ['Hurst', 'L', 'LambdaR', 'LambdaS', 'surfaceEnergy', 'rho', 'pulloff']

data = pd.read_csv(data_file)

# Hurst doesn't have any meaning at the moment, so it can be dropped
data.pop('Hurst')

print(data['pulloff'].mean())

data
# Out:
# 0.039270693135416666
#        L  lambdaR  lambdaS  surfaceEnergy       rho       pulloff
# 0    512      256        4       0.008652  0.037603  4.020000e-07
# 1    512      256        4       0.017304  0.059691  1.000000e-06
# 2    512      256        4       0.034609  0.094753  2.800000e-06
# 3    512      256        4       0.060566  0.137601  6.760000e-06
# 4    512      256        4       0.112480  0.207899  2.940000e-05
# ..   ...      ...      ...            ...       ...           ...
# 91  1024      128        2       0.951758  0.863281  2.372370e-02
# 92  1024      128        2       1.384375  1.108248  4.828920e-02
# 93  1024      128        2       1.990039  1.411591  8.272820e-02
# 94  1024      128        2       2.768750  1.759234  1.192725e-01
# 95  1024      128        2       3.893555  2.208168  2.017273e-01
#
# [96 rows x 6 columns]

# %%
dataplot = sns.heatmap(data.corr(), cmap="rocket", annot=True)

plt.show()

# %%
sns.pairplot(data[['surfaceEnergy', 'rho', 'pulloff']], hue='pulloff')

# %%
sns.set(style = "darkgrid")

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

x = data['rho']
y = data['surfaceEnergy']
z = data['pulloff']

ax.set_xlabel("rho")
ax.set_ylabel("surface Energy")
ax.set_zlabel("pulloff Force")

ax.scatter(x, y, z)

plt.show()

# %%
sns.histplot(data=data, x=data['pulloff'], binwidth=0.01)
# Out:
# <AxesSubplot: xlabel='pulloff', ylabel='Count'>

# %%
dataset = data.copy()

train_dataset = dataset.sample(frac=0.8)
test_dataset = dataset.drop(train_dataset.index)

X_train = train_dataset[['surfaceEnergy', 'rho']]
X_test = test_dataset[['surfaceEnergy', 'rho']]
Y_train = train_dataset['pulloff']
Y_test = test_dataset['pulloff']

display(Y_train.sort_values())
# Out:
# 77    1.340000e-07
# 78    3.950000e-07
# 0     4.020000e-07
# 20    5.080000e-07
# 42    6.260000e-07
#           ...
# 76    1.954523e-01
# 95    2.017273e-01
# 18    2.404730e-01
# 39    2.884550e-01
# 40    4.036770e-01
# Name: pulloff, Length: 77, dtype: float64

# %%
from sklearn import  linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# standardizing the data
scaler = StandardScaler()
scaler.fit(X_train)
scaler.fit(X_test)

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(train_dataset[['rho', 'surfaceEnergy']], train_dataset['pulloff'])
# Out:
# LinearRegression()

# %%
preds = regr.predict(test_dataset[['rho', 'surfaceEnergy']])

# The coefficients
print("Coefficients: \n", regr.coef_)
# The mean squared error
mse = mean_squared_error(test_dataset['pulloff'], preds)
print("Mean squared error: %.10f" % mse)
# The RSME
print("Root Mean squared error: %.10f" % np.sqrt(mse))
# The mean absolute error
print("Mean squared error: %.10f" % mean_absolute_error(test_dataset['pulloff'], preds))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.5f" % r2_score(test_dataset['pulloff'], preds))
# Out:
# Coefficients:
#  [-0.05073285  0.07519476]
# Mean squared error: 0.0002741713
# Root Mean squared error: 0.0165581187
# Mean squared error: 0.0114158350
# Coefficient of determination: 0.96375

# %%
# going a bit further
from sklearn.kernel_ridge import KernelRidge

for alpha in np.arange(0, 15.1, 0.1):
    print("alpha: %.1f" % alpha)
    krr = KernelRidge(alpha=alpha)
    krr.fit(train_dataset[['rho', 'surfaceEnergy']], train_dataset['pulloff'])

    preds = krr.predict(test_dataset[['rho', 'surfaceEnergy']])

    # The mean squared error
    mse = mean_squared_error(test_dataset['pulloff'], preds)
    print("Mean squared error: %.10f" % mse)
    # The RSME
    print("Root Mean squared error: %.10f" % np.sqrt(mse))
    # The mean absolute error
    print("Mean squared error: %.10f" % mean_absolute_error(test_dataset['pulloff'], preds))
    # The coefficient of determination: 1 is perfect prediction
    print("Coefficient of determination: %.5f" % r2_score(test_dataset['pulloff'], preds))
# Out:
# alpha: 0.0
# Mean squared error: 0.0002431927
# Root Mean squared error: 0.0155946358
# Mean squared error: 0.0103349553
# Coefficient of determination: 0.96784
# alpha: 0.1
# Mean squared error: 0.0002448564
# Root Mean squared error: 0.0156478894
# Mean squared error: 0.0104282279
# Coefficient of determination: 0.96762
# alpha: 0.2
# Mean squared error: 0.0002471095
# Root Mean squared error: 0.0157197175
# Mean squared error: 0.0105686464
# Coefficient of determination: 0.96732
# alpha: 0.3
# Mean squared error: 0.0002498383
# Root Mean squared error: 0.0158062726
# Mean squared error: 0.0107705358
# Coefficient of determination: 0.96696
# alpha: 0.4
# Mean squared error: 0.0002529493
# Root Mean squared error: 0.0159043810
# Mean squared error: 0.0109871183
# Coefficient of determination: 0.96655
# alpha: 0.5
# Mean squared error: 0.0002563659
# Root Mean squared error: 0.0160114310
# Mean squared error: 0.0112046726
# Coefficient of determination: 0.96610
# alpha: 0.6
# Mean squared error: 0.0002600245
# Root Mean squared error: 0.0161252763
# Mean squared error: 0.0114104513
# Coefficient of determination: 0.96562
# alpha: 0.7
# Mean squared error: 0.0002638726
# Root Mean squared error: 0.0162441570
# Mean squared error: 0.0116054152
# Coefficient of determination: 0.96511
# alpha: 0.8
# Mean squared error: 0.0002678666
# Root Mean squared error: 0.0163666318
# Mean squared error: 0.0117904234
# Coefficient of determination: 0.96458
# alpha: 0.9
# Mean squared error: 0.0002719703
# Root Mean squared error: 0.0164915228
# Mean squared error: 0.0119662461
# Coefficient of determination: 0.96404
# alpha: 1.0
# Mean squared error: 0.0002761536
# Root Mean squared error: 0.0166178697
# Mean squared error: 0.0121335762
# Coefficient of determination: 0.96348
# alpha: 1.1
# Mean squared error: 0.0002803914
# Root Mean squared error: 0.0167448913
# Mean squared error: 0.0122930384
# Coefficient of determination: 0.96292
# alpha: 1.2
# Mean squared error: 0.0002846628
# Root Mean squared error: 0.0168719544
# Mean squared error: 0.0124451978
# Coefficient of determination: 0.96236
# alpha: 1.3
# Mean squared error: 0.0002889506
# Root Mean squared error: 0.0169985480
# Mean squared error: 0.0125905665
# Coefficient of determination: 0.96179
# alpha: 1.4
# Mean squared error: 0.0002932403
# Root Mean squared error: 0.0171242616
# Mean squared error: 0.0127534777
# Coefficient of determination: 0.96122
# alpha: 1.5
# Mean squared error: 0.0002975200
# Root Mean squared error: 0.0172487679
# Mean squared error: 0.0129324272
# Coefficient of determination: 0.96066
# alpha: 1.6
# Mean squared error: 0.0003017797
# Root Mean squared error: 0.0173718082
# Mean squared error: 0.0131036960
# Coefficient of determination: 0.96010
# alpha: 1.7
# Mean squared error: 0.0003060114
# Root Mean squared error: 0.0174931803
# Mean squared error: 0.0132677769
# Coefficient of determination: 0.95954
# alpha: 1.8
# Mean squared error: 0.0003102082
# Root Mean squared error: 0.0176127288
# Mean squared error: 0.0134251213
# Coefficient of determination: 0.95898
# alpha: 1.9
# Mean squared error: 0.0003143648
# Root Mean squared error: 0.0177303366
# Mean squared error: 0.0135761435
# Coefficient of determination: 0.95843
# alpha: 2.0
# Mean squared error: 0.0003184768
# Root Mean squared error: 0.0178459185
# Mean squared error: 0.0137212246
# Coefficient of determination: 0.95789
# alpha: 2.1
# Mean squared error: 0.0003225406
# Root Mean squared error: 0.0179594153
# Mean squared error: 0.0138607157
# Coefficient of determination: 0.95735
# alpha: 2.2
# Mean squared error: 0.0003265534
# Root Mean squared error: 0.0180707893
# Mean squared error: 0.0139949407
# Coefficient of determination: 0.95682
# alpha: 2.3
# Mean squared error: 0.0003305131
# Root Mean squared error: 0.0181800201
# Mean squared error: 0.0141248112
# Coefficient of determination: 0.95630
# alpha: 2.4
# Mean squared error: 0.0003344181
# Root Mean squared error: 0.0182871020
# Mean squared error: 0.0142507339
# Coefficient of determination: 0.95578
# alpha: 2.5
# Mean squared error: 0.0003382672
# Root Mean squared error: 0.0183920408
# Mean squared error: 0.0143721734
# Coefficient of determination: 0.95527
# alpha: 2.6
# Mean squared error: 0.0003420595
# Root Mean squared error: 0.0184948518
# Mean squared error: 0.0144893709
# Coefficient of determination: 0.95477
# alpha: 2.7
# Mean squared error: 0.0003457948
# Root Mean squared error: 0.0185955577
# Mean squared error: 0.0146025505
# Coefficient of determination: 0.95428
# alpha: 2.8
# Mean squared error: 0.0003494726
# Root Mean squared error: 0.0186941876
# Mean squared error: 0.0147119208
# Coefficient of determination: 0.95379
# alpha: 2.9
# Mean squared error: 0.0003530932
# Root Mean squared error: 0.0187907751
# Mean squared error: 0.0148176762
# Coefficient of determination: 0.95331
# alpha: 3.0
# Mean squared error: 0.0003566567
# Root Mean squared error: 0.0188853577
# Mean squared error: 0.0149199981
# Coefficient of determination: 0.95284
# alpha: 3.1
# Mean squared error: 0.0003601636
# Root Mean squared error: 0.0189779756
# Mean squared error: 0.0150190560
# Coefficient of determination: 0.95238
# alpha: 3.2
# Mean squared error: 0.0003636142
# Root Mean squared error: 0.0190686712
# Mean squared error: 0.0151150083
# Coefficient of determination: 0.95192
# alpha: 3.3
# /home/marc/.local/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# Mean squared error: 0.0003670094
# Root Mean squared error: 0.0191574883
# Mean squared error: 0.0152080033
# Coefficient of determination: 0.95147
# alpha: 3.4
# Mean squared error: 0.0003703497
# Root Mean squared error: 0.0192444718
# Mean squared error: 0.0152981802
# Coefficient of determination: 0.95103
# alpha: 3.5
# Mean squared error: 0.0003736360
# Root Mean squared error: 0.0193296670
# Mean squared error: 0.0153856694
# Coefficient of determination: 0.95059
# alpha: 3.6
# Mean squared error: 0.0003768692
# Root Mean squared error: 0.0194131196
# Mean squared error: 0.0154705934
# Coefficient of determination: 0.95017
# alpha: 3.7
# Mean squared error: 0.0003800502
# Root Mean squared error: 0.0194948752
# Mean squared error: 0.0155530675
# Coefficient of determination: 0.94975
# alpha: 3.8
# Mean squared error: 0.0003831798
# Root Mean squared error: 0.0195749789
# Mean squared error: 0.0156332001
# Coefficient of determination: 0.94933
# alpha: 3.9
# Mean squared error: 0.0003862591
# Root Mean squared error: 0.0196534757
# Mean squared error: 0.0157110931
# Coefficient of determination: 0.94893
# alpha: 4.0
# Mean squared error: 0.0003892891
# Root Mean squared error: 0.0197304097
# Mean squared error: 0.0157868429
# Coefficient of determination: 0.94852
# alpha: 4.1
# Mean squared error: 0.0003922707
# Root Mean squared error: 0.0198058242
# Mean squared error: 0.0158605402
# Coefficient of determination: 0.94813
# alpha: 4.2
# Mean squared error: 0.0003952049
# Root Mean squared error: 0.0198797620
# Mean squared error: 0.0159322708
# Coefficient of determination: 0.94774
# alpha: 4.3
# Mean squared error: 0.0003980929
# Root Mean squared error: 0.0199522647
# Mean squared error: 0.0160021157
# Coefficient of determination: 0.94736
# alpha: 4.4
# Mean squared error: 0.0004009355
# Root Mean squared error: 0.0200233731
# Mean squared error: 0.0160701515
# Coefficient of determination: 0.94698
# alpha: 4.5
# Mean squared error: 0.0004037337
# Root Mean squared error: 0.0200931268
# Mean squared error: 0.0161364507
# Coefficient of determination: 0.94661
# alpha: 4.6
# Mean squared error: 0.0004064887
# Root Mean squared error: 0.0201615647
# Mean squared error: 0.0162010821
# Coefficient of determination: 0.94625
# alpha: 4.7
# Mean squared error: 0.0004092013
# Root Mean squared error: 0.0202287244
# Mean squared error: 0.0162641107
# Coefficient of determination: 0.94589
# alpha: 4.8
# Mean squared error: 0.0004118725
# Root Mean squared error: 0.0202946424
# Mean squared error: 0.0163255983
# Coefficient of determination: 0.94554
# alpha: 4.9
# Mean squared error: 0.0004145033
# Root Mean squared error: 0.0203593545
# Mean squared error: 0.0163856036
# Coefficient of determination: 0.94519
# alpha: 5.0
# Mean squared error: 0.0004170946
# Root Mean squared error: 0.0204228951
# Mean squared error: 0.0164441821
# Coefficient of determination: 0.94485
# alpha: 5.1
# Mean squared error: 0.0004196474
# Root Mean squared error: 0.0204852977
# Mean squared error: 0.0165013870
# Coefficient of determination: 0.94451
# alpha: 5.2
# Mean squared error: 0.0004221626
# Root Mean squared error: 0.0205465949
# Mean squared error: 0.0165572684
# Coefficient of determination: 0.94418
# alpha: 5.3
# Mean squared error: 0.0004246410
# Root Mean squared error: 0.0206068181
# Mean squared error: 0.0166118744
# Coefficient of determination: 0.94385
# alpha: 5.4
# Mean squared error: 0.0004270835
# Root Mean squared error: 0.0206659978
# Mean squared error: 0.0166652505
# Coefficient of determination: 0.94353
# alpha: 5.5
# Mean squared error: 0.0004294910
# Root Mean squared error: 0.0207241636
# Mean squared error: 0.0167174401
# Coefficient of determination: 0.94321
# alpha: 5.6
# Mean squared error: 0.0004318643
# Root Mean squared error: 0.0207813442
# Mean squared error: 0.0167684848
# Coefficient of determination: 0.94289
# alpha: 5.7
# Mean squared error: 0.0004342042
# Root Mean squared error: 0.0208375671
# Mean squared error: 0.0168184241
# Coefficient of determination: 0.94259
# alpha: 5.8
# Mean squared error: 0.0004365116
# Root Mean squared error: 0.0208928593
# Mean squared error: 0.0168672956
# Coefficient of determination: 0.94228
# alpha: 5.9
# Mean squared error: 0.0004387871
# Root Mean squared error: 0.0209472466
# Mean squared error: 0.0169151354
# Coefficient of determination: 0.94198
# alpha: 6.0
# Mean squared error: 0.0004410317
# Root Mean squared error: 0.0210007542
# Mean squared error: 0.0169619780
# Coefficient of determination: 0.94168
# alpha: 6.1
# Mean squared error: 0.0004432459
# Root Mean squared error: 0.0210534065
# Mean squared error: 0.0170078562
# Coefficient of determination: 0.94139
# alpha: 6.2
# Mean squared error: 0.0004454306
# Root Mean squared error: 0.0211052269
# Mean squared error: 0.0170528016
# Coefficient of determination: 0.94110
# alpha: 6.3
# Mean squared error: 0.0004475864
# Root Mean squared error: 0.0211562382
# Mean squared error: 0.0170968441
# Coefficient of determination: 0.94082
# alpha: 6.4
# Mean squared error: 0.0004497140
# Root Mean squared error: 0.0212064624
# Mean squared error: 0.0171400127
# Coefficient of determination: 0.94053
# alpha: 6.5
# Mean squared error: 0.0004518142
# Root Mean squared error: 0.0212559208
# Mean squared error: 0.0171823349
# Coefficient of determination: 0.94026
# alpha: 6.6
# Mean squared error: 0.0004538874
# Root Mean squared error: 0.0213046341
# Mean squared error: 0.0172238373
# Coefficient of determination: 0.93998
# alpha: 6.7
# Mean squared error: 0.0004559345
# Root Mean squared error: 0.0213526223
# Mean squared error: 0.0172645451
# Coefficient of determination: 0.93971
# alpha: 6.8
# Mean squared error: 0.0004579559
# Root Mean squared error: 0.0213999046
# Mean squared error: 0.0173044828
# Coefficient of determination: 0.93944
# alpha: 6.9
# Mean squared error: 0.0004599524
# Root Mean squared error: 0.0214464997
# Mean squared error: 0.0173436735
# Coefficient of determination: 0.93918
# alpha: 7.0
# Mean squared error: 0.0004619244
# Root Mean squared error: 0.0214924258
# Mean squared error: 0.0173821399
# Coefficient of determination: 0.93892
# alpha: 7.1
# Mean squared error: 0.0004638725
# Root Mean squared error: 0.0215377004
# Mean squared error: 0.0174199033
# Coefficient of determination: 0.93866
# alpha: 7.2
# Mean squared error: 0.0004657974
# Root Mean squared error: 0.0215823405
# Mean squared error: 0.0174569844
# Coefficient of determination: 0.93841
# alpha: 7.3
# Mean squared error: 0.0004676996
# Root Mean squared error: 0.0216263624
# Mean squared error: 0.0174934032
# Coefficient of determination: 0.93816
# alpha: 7.4
# Mean squared error: 0.0004695795
# Root Mean squared error: 0.0216697821
# Mean squared error: 0.0175291786
# Coefficient of determination: 0.93791
# alpha: 7.5
# Mean squared error: 0.0004714377
# Root Mean squared error: 0.0217126151
# Mean squared error: 0.0175643291
# Coefficient of determination: 0.93766
# alpha: 7.6
# Mean squared error: 0.0004732746
# Root Mean squared error: 0.0217548761
# Mean squared error: 0.0175988724
# Coefficient of determination: 0.93742
# alpha: 7.7
# Mean squared error: 0.0004750909
# Root Mean squared error: 0.0217965798
# Mean squared error: 0.0176328254
# Coefficient of determination: 0.93718
# alpha: 7.8
# Mean squared error: 0.0004768869
# Root Mean squared error: 0.0218377401
# Mean squared error: 0.0176662046
# Coefficient of determination: 0.93694
# alpha: 7.9
# Mean squared error: 0.0004786631
# Root Mean squared error: 0.0218783707
# Mean squared error: 0.0176990257
# Coefficient of determination: 0.93671
# alpha: 8.0
# Mean squared error: 0.0004804200
# Root Mean squared error: 0.0219184846
# Mean squared error: 0.0177313040
# Coefficient of determination: 0.93647
# alpha: 8.1
# Mean squared error: 0.0004821579
# Root Mean squared error: 0.0219580947
# Mean squared error: 0.0177630540
# Coefficient of determination: 0.93624
# alpha: 8.2
# Mean squared error: 0.0004838774
# Root Mean squared error: 0.0219972132
# Mean squared error: 0.0177942899
# Coefficient of determination: 0.93602
# alpha: 8.3
# Mean squared error: 0.0004855788
# Root Mean squared error: 0.0220358523
# Mean squared error: 0.0178250254
# Coefficient of determination: 0.93579
# alpha: 8.4
# Mean squared error: 0.0004872625
# Root Mean squared error: 0.0220740236
# Mean squared error: 0.0178552735
# Coefficient of determination: 0.93557
# alpha: 8.5
# Mean squared error: 0.0004889290
# Root Mean squared error: 0.0221117383
# Mean squared error: 0.0178850471
# Coefficient of determination: 0.93535
# alpha: 8.6
# Mean squared error: 0.0004905785
# Root Mean squared error: 0.0221490074
# Mean squared error: 0.0179143583
# Coefficient of determination: 0.93513
# alpha: 8.7
# Mean squared error: 0.0004922116
# Root Mean squared error: 0.0221858416
# Mean squared error: 0.0179432190
# Coefficient of determination: 0.93492
# alpha: 8.8
# Mean squared error: 0.0004938284
# Root Mean squared error: 0.0222222511
# Mean squared error: 0.0179716405
# Coefficient of determination: 0.93470
# alpha: 8.9
# Mean squared error: 0.0004954295
# Root Mean squared error: 0.0222582459
# Mean squared error: 0.0179996341
# Coefficient of determination: 0.93449
# alpha: 9.0
# Mean squared error: 0.0004970151
# Root Mean squared error: 0.0222938358
# Mean squared error: 0.0180272102
# Coefficient of determination: 0.93428
# alpha: 9.1
# Mean squared error: 0.0004985856
# Root Mean squared error: 0.0223290303
# Mean squared error: 0.0180543793
# Coefficient of determination: 0.93407
# alpha: 9.2
# Mean squared error: 0.0005001413
# Root Mean squared error: 0.0223638384
# Mean squared error: 0.0180811514
# Coefficient of determination: 0.93387
# alpha: 9.3
# Mean squared error: 0.0005016825
# Root Mean squared error: 0.0223982691
# Mean squared error: 0.0181075360
# Coefficient of determination: 0.93366
# alpha: 9.4
# Mean squared error: 0.0005032095
# Root Mean squared error: 0.0224323310
# Mean squared error: 0.0181335426
# Coefficient of determination: 0.93346
# alpha: 9.5
# Mean squared error: 0.0005047226
# Root Mean squared error: 0.0224660325
# Mean squared error: 0.0181591802
# Coefficient of determination: 0.93326
# alpha: 9.6
# Mean squared error: 0.0005062222
# Root Mean squared error: 0.0224993818
# Mean squared error: 0.0181844576
# Coefficient of determination: 0.93306
# alpha: 9.7
# Mean squared error: 0.0005077085
# Root Mean squared error: 0.0225323868
# Mean squared error: 0.0182093832
# Coefficient of determination: 0.93287
# alpha: 9.8
# Mean squared error: 0.0005091817
# Root Mean squared error: 0.0225650553
# Mean squared error: 0.0182339653
# Coefficient of determination: 0.93267
# alpha: 9.9
# Mean squared error: 0.0005106422
# Root Mean squared error: 0.0225973947
# Mean squared error: 0.0182582117
# Coefficient of determination: 0.93248
# alpha: 10.0
# Mean squared error: 0.0005120903
# Root Mean squared error: 0.0226294123
# Mean squared error: 0.0182821304
# Coefficient of determination: 0.93229
# alpha: 10.1
# Mean squared error: 0.0005135261
# Root Mean squared error: 0.0226611151
# Mean squared error: 0.0183057286
# Coefficient of determination: 0.93210
# alpha: 10.2
# Mean squared error: 0.0005149500
# Root Mean squared error: 0.0226925102
# Mean squared error: 0.0183290137
# Coefficient of determination: 0.93191
# alpha: 10.3
# Mean squared error: 0.0005163622
# Root Mean squared error: 0.0227236042
# Mean squared error: 0.0183519927
# Coefficient of determination: 0.93172
# alpha: 10.4
# Mean squared error: 0.0005177629
# Root Mean squared error: 0.0227544036
# Mean squared error: 0.0183746725
# Coefficient of determination: 0.93154
# alpha: 10.5
# Mean squared error: 0.0005191523
# Root Mean squared error: 0.0227849148
# Mean squared error: 0.0183970596
# Coefficient of determination: 0.93135
# alpha: 10.6
# Mean squared error: 0.0005205308
# Root Mean squared error: 0.0228151440
# Mean squared error: 0.0184191606
# Coefficient of determination: 0.93117
# alpha: 10.7
# Mean squared error: 0.0005218985
# Root Mean squared error: 0.0228450971
# Mean squared error: 0.0184409815
# Coefficient of determination: 0.93099
# alpha: 10.8
# Mean squared error: 0.0005232556
# Root Mean squared error: 0.0228747800
# Mean squared error: 0.0184625285
# Coefficient of determination: 0.93081
# alpha: 10.9
# Mean squared error: 0.0005246023
# Root Mean squared error: 0.0229041985
# Mean squared error: 0.0184838075
# Coefficient of determination: 0.93063
# alpha: 11.0
# Mean squared error: 0.0005259389
# Root Mean squared error: 0.0229333580
# Mean squared error: 0.0185048242
# Coefficient of determination: 0.93046
# alpha: 11.1
# Mean squared error: 0.0005272656
# Root Mean squared error: 0.0229622641
# Mean squared error: 0.0185255842
# Coefficient of determination: 0.93028
# alpha: 11.2
# Mean squared error: 0.0005285825
# Root Mean squared error: 0.0229909219
# Mean squared error: 0.0185460927
# Coefficient of determination: 0.93011
# alpha: 11.3
# Mean squared error: 0.0005298899
# Root Mean squared error: 0.0230193365
# Mean squared error: 0.0185663552
# Coefficient of determination: 0.92993
# alpha: 11.4
# Mean squared error: 0.0005311879
# Root Mean squared error: 0.0230475131
# Mean squared error: 0.0185863766
# Coefficient of determination: 0.92976
# alpha: 11.5
# Mean squared error: 0.0005324767
# Root Mean squared error: 0.0230754564
# Mean squared error: 0.0186061620
# Coefficient of determination: 0.92959
# alpha: 11.6
# Mean squared error: 0.0005337565
# Root Mean squared error: 0.0231031712
# Mean squared error: 0.0186257162
# Coefficient of determination: 0.92942
# alpha: 11.7
# Mean squared error: 0.0005350275
# Root Mean squared error: 0.0231306622
# Mean squared error: 0.0186450438
# Coefficient of determination: 0.92925
# alpha: 11.8
# Mean squared error: 0.0005362899
# Root Mean squared error: 0.0231579338
# Mean squared error: 0.0186641494
# Coefficient of determination: 0.92909
# alpha: 11.9
# Mean squared error: 0.0005375438
# Root Mean squared error: 0.0231849905
# Mean squared error: 0.0186830375
# Coefficient of determination: 0.92892
# alpha: 12.0
# Mean squared error: 0.0005387894
# Root Mean squared error: 0.0232118365
# Mean squared error: 0.0187017123
# Coefficient of determination: 0.92876
# alpha: 12.1
# Mean squared error: 0.0005400268
# Root Mean squared error: 0.0232384760
# Mean squared error: 0.0187201782
# Coefficient of determination: 0.92859
# alpha: 12.2
# Mean squared error: 0.0005412562
# Root Mean squared error: 0.0232649131
# Mean squared error: 0.0187384392
# Coefficient of determination: 0.92843
# alpha: 12.3
# Mean squared error: 0.0005424778
# Root Mean squared error: 0.0232911519
# Mean squared error: 0.0187564992
# Coefficient of determination: 0.92827
# alpha: 12.4
# Mean squared error: 0.0005436916
# Root Mean squared error: 0.0233171961
# Mean squared error: 0.0187743622
# Coefficient of determination: 0.92811
# alpha: 12.5
# Mean squared error: 0.0005448980
# Root Mean squared error: 0.0233430495
# Mean squared error: 0.0187920320
# Coefficient of determination: 0.92795
# alpha: 12.6
# Mean squared error: 0.0005460969
# Root Mean squared error: 0.0233687160
# Mean squared error: 0.0188095122
# Coefficient of determination: 0.92779
# alpha: 12.7
# Mean squared error: 0.0005472885
# Root Mean squared error: 0.0233941990
# Mean squared error: 0.0188268064
# Coefficient of determination: 0.92763
# alpha: 12.8
# Mean squared error: 0.0005484731
# Root Mean squared error: 0.0234195021
# Mean squared error: 0.0188439182
# Coefficient of determination: 0.92748
# alpha: 12.9
# Mean squared error: 0.0005496506
# Root Mean squared error: 0.0234446288
# Mean squared error: 0.0188608509
# Coefficient of determination: 0.92732
# alpha: 13.0
# Mean squared error: 0.0005508213
# Root Mean squared error: 0.0234695824
# Mean squared error: 0.0188776080
# Coefficient of determination: 0.92717
# alpha: 13.1
# Mean squared error: 0.0005519852
# Root Mean squared error: 0.0234943661
# Mean squared error: 0.0188941925
# Coefficient of determination: 0.92701
# alpha: 13.2
# Mean squared error: 0.0005531426
# Root Mean squared error: 0.0235189833
# Mean squared error: 0.0189106078
# Coefficient of determination: 0.92686
# alpha: 13.3
# Mean squared error: 0.0005542934
# Root Mean squared error: 0.0235434370
# Mean squared error: 0.0189268568
# Coefficient of determination: 0.92671
# alpha: 13.4
# Mean squared error: 0.0005554379
# Root Mean squared error: 0.0235677302
# Mean squared error: 0.0189429427
# Coefficient of determination: 0.92655
# alpha: 13.5
# Mean squared error: 0.0005565761
# Root Mean squared error: 0.0235918661
# Mean squared error: 0.0189588683
# Coefficient of determination: 0.92640
# alpha: 13.6
# Mean squared error: 0.0005577082
# Root Mean squared error: 0.0236158474
# Mean squared error: 0.0189746365
# Coefficient of determination: 0.92625
# alpha: 13.7
# Mean squared error: 0.0005588343
# Root Mean squared error: 0.0236396771
# Mean squared error: 0.0189902502
# Coefficient of determination: 0.92611
# alpha: 13.8
# Mean squared error: 0.0005599545
# Root Mean squared error: 0.0236633579
# Mean squared error: 0.0190057120
# Coefficient of determination: 0.92596
# alpha: 13.9
# Mean squared error: 0.0005610689
# Root Mean squared error: 0.0236868925
# Mean squared error: 0.0190210246
# Coefficient of determination: 0.92581
# alpha: 14.0
# Mean squared error: 0.0005621776
# Root Mean squared error: 0.0237102837
# Mean squared error: 0.0190361906
# Coefficient of determination: 0.92566
# alpha: 14.1
# Mean squared error: 0.0005632806
# Root Mean squared error: 0.0237335340
# Mean squared error: 0.0190512126
# Coefficient of determination: 0.92552
# alpha: 14.2
# Mean squared error: 0.0005643782
# Root Mean squared error: 0.0237566460
# Mean squared error: 0.0190660931
# Coefficient of determination: 0.92537
# alpha: 14.3
# Mean squared error: 0.0005654704
# Root Mean squared error: 0.0237796221
# Mean squared error: 0.0190808344
# Coefficient of determination: 0.92523
# alpha: 14.4
# Mean squared error: 0.0005665573
# Root Mean squared error: 0.0238024649
# Mean squared error: 0.0190954390
# Coefficient of determination: 0.92508
# alpha: 14.5
# Mean squared error: 0.0005676390
# Root Mean squared error: 0.0238251766
# Mean squared error: 0.0191099092
# Coefficient of determination: 0.92494
# alpha: 14.6
# Mean squared error: 0.0005687156
# Root Mean squared error: 0.0238477596
# Mean squared error: 0.0191242472
# Coefficient of determination: 0.92480
# alpha: 14.7
# Mean squared error: 0.0005697872
# Root Mean squared error: 0.0238702162
# Mean squared error: 0.0191384553
# Coefficient of determination: 0.92466
# alpha: 14.8
# Mean squared error: 0.0005708539
# Root Mean squared error: 0.0238925487
# Mean squared error: 0.0191525356
# Coefficient of determination: 0.92452
# alpha: 14.9
# Mean squared error: 0.0005719157
# Root Mean squared error: 0.0239147591
# Mean squared error: 0.0191664903
# Coefficient of determination: 0.92438
# alpha: 15.0
# Mean squared error: 0.0005729728
# Root Mean squared error: 0.0239368497
# Mean squared error: 0.0191803213
# Coefficient of determination: 0.92424

# %%
from sklearn.linear_model import LassoLarsIC

lasso_lars_ic = make_pipeline(StandardScaler(), LassoLarsIC(criterion="aic")).fit(X_train, Y_train)
